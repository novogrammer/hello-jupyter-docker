# %%
# 諸々確認
# !uname -a
print("----")
# !cat /etc/os-release
print("----")
# !nvidia-smi
#print("----")
#!ls $rundir
#print("----")
#!pwd
# Out:
# Linux 903d7fa43c11 6.6.16-linuxkit #1 SMP Fri Feb 16 11:54:02 UTC 2024 x86_64 x86_64 x86_64 GNU/Linux
# ----
# PRETTY_NAME="Ubuntu 22.04.4 LTS"
# NAME="Ubuntu"
# VERSION_ID="22.04"
# VERSION="22.04.4 LTS (Jammy Jellyfish)"
# VERSION_CODENAME=jammy
# ID=ubuntu
# ID_LIKE=debian
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# UBUNTU_CODENAME=jammy
# ----
# /usr/bin/sh: 1: nvidia-smi: not found

# %%
# !python --version
# Out:
# Python 3.11.5

# %%
# !/usr/games/sl
# Out:
# | _|_|/ |   |-__/ =| o |=-~O==|/-=|___|=    |    \__/_D _|  |__;1H|/|/-\_|(| ___/ =|/-=\_/_D _|(_| _|/ |__/ =||/-=|=_D _||(_)| _==_D _|  ||(_)-/     ||      || _|/ |   |__/ =| o ||/-=|___|(@(_D _|  |_|(_)---  |/     |  ||      |  || _||/ |   |-__/ =| o |=-~|/-=|___|=  \_/      \O_D _|  |_[1(@@(    )(@@@)_D _|  |_|(_)---  |   H/     |  |   H|      |  |   H| _|___H|/ |   |-__/ =| o |=-O==|/-=|___|=    |_D _|  |_/|(_)---  |   H\| _|___H_|/ |   |-__/ =| o |=-~~\  /|/-=|___|=O=====O\_/      \__/  \
# ...
